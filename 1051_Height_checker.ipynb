# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
class Solution:
    def heightChecker(self, heights: List[int]) -> int:
        h = heights.copy()
        c = 0
        heights.sort()
        print(h)
        for i in range(len(h)):
            if h[i] != heights[i]:
                c = c+1
        return c
