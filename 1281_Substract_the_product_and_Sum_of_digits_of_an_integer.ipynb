# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
class Solution:
    def subtractProductAndSum(self, n: int) -> int:
        l =[int(i) for i in str(n)]
        print(l)
        n_sum = 0
        n_mul = 1
        for i in l:
            n_mul = n_mul*i

        n_sum = sum(l)
        return n_mul-n_sum
