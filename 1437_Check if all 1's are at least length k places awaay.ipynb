# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Solution in python

# %%
class Solution:
    def kLengthApart(self, nums: List[int], k: int) -> bool:
#         z = 0
#         c = k
#         l = []
#         for i in range(len(nums)):
#             if nums[i]!=1:
#                 z+=1
#             if nums[i]==1:
#                 c = min(k,z)
#                 print(c)
#                 z = 0
#                 # if c!=0:
#                     # return False
#         # print(f" min 0 in two 1 {c}")
#         if nums.count(1)==1:
#             return True
#         if c>=k:
#             return True
#         else:
#             return False


        z = 0
        first_one = False
        
        for i in range(len(nums)):
            if nums[i] == 1:
                
                if first_one:
                    if z < k:
                        return False
                
               
                first_one = True
                z = 0
            else:
                z += 1
                
        return True
