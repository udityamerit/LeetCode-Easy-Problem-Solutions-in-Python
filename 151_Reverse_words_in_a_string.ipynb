# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
class Solution:
    def reverseWords(self, s: str) -> str:
        w = " ".join(s.split()[::-1])
        return w
