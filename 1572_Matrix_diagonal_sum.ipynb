# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
class Solution:
    def diagonalSum(self, mat: List[List[int]]) -> int:
        l =[]
        l1 =[]
        j = len(mat)-1
        for i in range(len(mat)):
            l.append(mat[i][i])
            if i==j:
                j = j-1
                continue
                
            else:
                print(i,j)
                print(mat[i][j])
                l1.append(mat[i][j])         
            j = j-1
        print(l)
        l = sum(l+l1)
        print(l1)
        return l
