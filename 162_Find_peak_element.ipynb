# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
class Solution:
    def findPeakElement(self, nums: List[int]) -> int:
        k = max(nums)
        for i in range(len(nums)):
            if nums[i]==k:
                return i
