# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
class Solution:
    def maximumGap(self, nums: List[int]) -> int:
        c = []
        nums.sort()
        if len(nums)<2:
            return 0
        else:
            for i in range(len(nums)-1):
                c.append(nums[i+1]-nums[i])
        return max(c)
