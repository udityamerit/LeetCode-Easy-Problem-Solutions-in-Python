# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
class Solution:
    def truncateSentence(self, s: str, k: int) -> str:
        w = s.split()[:k]
        return " ".join(w)
