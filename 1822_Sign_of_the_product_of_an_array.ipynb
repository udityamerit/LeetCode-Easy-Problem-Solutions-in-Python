# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
class Solution:
    def arraySign(self, nums: List[int]) -> int:
        n = len(nums)
        s = 1
        for elements in nums:
            s = s*elements  
        if s>0:
            return 1
        elif s==0:
            return 0
        else:
            return -1
