# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
class Solution:
    def getLucky(self, s: str, k: int) -> int:
        c = [(str(ord(i)-96)) for i in s]
        c = "".join(c)
        print(c)
        print(type(c))
        l = [int(i) for i in c]
        print(l)
        m = sum(l)

        if k<2:
            return sum(l)
        else:
        #    l = []
           for i in range(k-1):

                m = [int(i) for i in str(m)]
                m = sum(m)
                print(m)
            
        return m
