# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
import math
class Solution:
    def findGCD(self, nums: List[int]) -> int:
        ans = math.gcd(x,y)
        return ans
