# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
class Solution:
    def areNumbersAscending(self, s: str) -> bool:
        s = [int(word) for word in s.split() if word.isdigit()]
        print(s)
        l = list(set(s))
        l.sort()
        print(l)

        return l==s
