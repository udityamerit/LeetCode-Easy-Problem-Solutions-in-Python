# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
class Solution:
    def isSameAfterReversals(self, num: int) -> bool:
        m = num
        Sum = 0
        for i in range(2):
            Sum = 0

            while(num>0):
                r = num%10
                Sum = (Sum*10)+r
                num = num//10
            print(Sum)    
            num = Sum
        
        if Sum==m:
            return True

# %% [markdown]
# #### Solution 2

# %%
class Solution:
    def isSameAfterReversals(self, num: int) -> bool:
        
        if num == 0:
            return True
        val = str(num)
        val = val[::-1]
        val = str(int(val))
        val = val[::-1]
        print(val)
        return num == int(val)
