# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
class Solution:
    def findFinalValue(self, nums: List[int], original: int) -> int:
        i = 0
        while (i<len(nums)):
            if original in nums:
                original = original*2
            i = i+1
        return original
