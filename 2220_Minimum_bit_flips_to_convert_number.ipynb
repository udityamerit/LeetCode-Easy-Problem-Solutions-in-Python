# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
class Solution:
    def minBitFlips(self, start: int, goal: int) -> int:

        l = bin(start)
        c = 0
        l = l[2::]
        s = bin(goal)
        s = s[2::]
        l = [i for i in l]
        s = [ i for i in s]
        print(l,s)

        while len(s)!=len(l):
            if len(s)<len(l):
                s.insert(0,0)
            else:
                l.insert(0,0)
        print(l)
        print(s)

        for i in range(len(l)):
            if l[i] != s[i]:

                c=c+1
        
        return c

# %% [markdown]
# #### Solution 2

# %%
class Solution:
    def minBitFlips(self, start: int, goal: int) -> int:
     
        bit_value = start^goal
        return bin(bit_value).count('1')
