# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Soluton 1

# %%
class Solution:
    def intersection(self, nums: List[List[int]]) -> List[int]:

        arr = nums[0]
        if len(nums)==1:
            return sorted(nums[0])
            
        for i in range(len(nums)-1):
            arr = list(set(sorted(arr)).intersection(sorted(nums[i+1])))
            print(arr)
        arr.sort()
        
        return arr

# %% [markdown]
# #### Solution 2

# %%
class Solution:
    def intersection(self, nums: List[List[int]]) -> List[int]:
        
        common= set(nums[0])
        for i in nums[1:]:
            common.intersection_update(i)
        return sorted(common)
