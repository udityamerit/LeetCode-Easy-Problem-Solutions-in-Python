# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
class Solution:
    def isPowerOfTwo(self, n: int) -> bool:
        if n<=0:
            return False
        value = log10(n)/log10(2)
        return value==int(value)
