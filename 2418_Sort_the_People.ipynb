# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
from collections import Counter
class Solution:
    def sortPeople(self, names: List[str], heights: List[int]) -> List[str]:
        
        z = tuple(zip(tuple(heights), tuple(names)))
        print(list(z))
        z =sorted(z)
        print(z)
        l = [z[i][j] for i in range(len(z)) for j in range(len( z[i]))]
        l.reverse()
        print(l)
        k = [l[i] for i in range(0, len(l),2)]
        return (k)

# %% [markdown]
# #### Solution 2

# %%
from collections import Counter
class Solution:
    def sortPeople(self, names: List[str], heights: List[int]) -> List[str]:
        
        z = tuple(zip(tuple(heights), tuple(names)))
        print(list(z))
        z =sorted(z)
        print(z)
        l = []
        for i in range(len(z)):
            for j in range(len(z[i])):
                l.append(z[i][j])
        l.reverse()
        print(l)
        k = []
        for i in range(0, len(l), 2):
            k.append(l[i])
        return (k)
