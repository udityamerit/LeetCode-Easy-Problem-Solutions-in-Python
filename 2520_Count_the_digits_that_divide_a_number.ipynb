# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
class Solution:
    def countDigits(self, num: int) -> int:
        s = str(num)
        s = [x for x in s]
        ans = []
        for i in s:
            if num%int(i)==0:
                ans.append(i)
        return len(ans)
