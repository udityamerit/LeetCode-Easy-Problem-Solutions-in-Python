# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
class Solution:
    def passThePillow(self, n: int, time: int) -> int:

        ans = 1
        k = ans
        for i in range(time):
            ans += k
            print(ans)
            if ans == 1 or ans == n:
                k *= -1
                print(ans)
        return ans
