# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
class Solution:
    def maximizeSum(self, nums: List[int], k: int) -> int:
        ans = 0
        for i in range(k):
            m = max(nums)
            nums.remove(m)
            nums.append(m+1)
            ans = ans+m
        print(nums)
        return ans
