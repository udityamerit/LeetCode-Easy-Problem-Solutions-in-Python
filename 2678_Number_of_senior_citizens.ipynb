# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
class Solution:
    def countSeniors(self, details: List[str]) -> int:
        l = [i[11:13] for i in details]
        print(l)
        c = 0
        for i in l:
            if int(i)>60:
                c = c+1
        return c
