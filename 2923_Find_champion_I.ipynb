# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
class Solution:
    def findChampion(self, grid: List[List[int]]) -> int:
        l = []
        for score in grid:
            l.append(sum(score))
        m = max(l)
        for i in range(len(grid)):
            if (sum(grid[i]))==m:
                return i
