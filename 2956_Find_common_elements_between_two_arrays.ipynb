# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
class Solution:
    def findIntersectionValues(self, nums1: List[int], nums2: List[int]) -> List[int]:
        l = [i for i in range(len(nums1)) if nums1[i] in nums2]
        s = [i for i in range(len(nums2)) if nums2[i] in nums1]
        return [len(l),len(s)]
