# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution in python

# %%
class Solution:
    def minimumCost(self, nums: List[int]) -> int:
        if len(nums)==3:
            return sum(nums)
        else:
            l = nums[0]
            s = sorted(nums[1:])
            print(s)
            return l+s[0]+s[1]
