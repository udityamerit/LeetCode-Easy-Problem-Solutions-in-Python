# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
class Solution:
    def convertDateToBinary(self, date: str) -> str:
        l = date.split("-")
        l = [(bin(int(i))[2::]) for i in l]
        l = "-".join(l)
        return l
