# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1 in python

# %%
class Solution:
    def largestInteger(self, nums: List[int], k: int) -> int:
        ans = []
        for i in range(len(nums)):
            for j in range(i+1, len(nums)+1):
                if len(nums[i:j])==k:
                    ans.append(nums[i:j])

        # print(ans)
        d =[]
        # c = 0
        for i in nums:
            c = 0
            for j in range(len(ans)):
                if i in ans[j]:
                    c+=1
            
            if c==1:
                d.append(i)
        
        if len(d)!=0:
            return max(d)
        else:
            return -1

# %% [markdown]
# #### Solution 2 in python

# %%
class Solution:
    def largestInteger(self, nums: List[int], k: int) -> int:
        
        if k==1:
            for i in sorted(nums, reverse=True):
                val = nums.count(i)
                if val==1:
                    return i
            return -1

        elif k==len(nums):
            return max(nums)
        
        else:
            for i in sorted ([nums[0], nums[-1]], reverse = True):
                # print(sorted([nums[0], nums[-1]]))
                print(i, nums.count(i))
                if nums.count(i)==1:
                    return i
            return -1
