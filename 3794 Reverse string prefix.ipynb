# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution

# %%
class Solution:
    def reversePrefix(self, s: str, k: int) -> str:
        s1 = list(s[:k])
        s2 = s[k:]
        s1.reverse()
        s3 = ''
        for i in s1:
            s3 = s3+i
        return s3+s2
