# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
class Solution:
    def countSegments(self, s: str) -> int:

        l = s.split()
        return len(l)

# %% [markdown]
# #### Solution 2

# %%
class Solution:
    def countSegments(self, s: str) -> int:
        
        return len(s.split())
