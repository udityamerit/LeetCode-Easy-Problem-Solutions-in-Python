# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
class Solution:
    def findMaxConsecutiveOnes(self, nums: List[int]) -> int:
        l = []
        c = 0
        for i in nums:
            if  i == 0:
                c = 0
            else:
                c = c+1
            l.append(c)
        return max(l)
