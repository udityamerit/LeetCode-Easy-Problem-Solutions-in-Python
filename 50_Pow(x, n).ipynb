# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
import math
class Solution:
    def myPow(self, x: float, n: int) -> float:
        # x^n
        m = math.pow(x,n)
        return m
