# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
class Solution:
    def reverseWords(self, s: str) -> str:
        s = s.split()
        ans = []
        for i in range(len(s)):
            ans.append(s[i][::-1])
        ans = " ".join(ans)
        return ans
