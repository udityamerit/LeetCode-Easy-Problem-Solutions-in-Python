# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
class Solution:
    def lengthOfLastWord(self, s: str) -> int:
       s = s.split()
       i = s[-1]
       return len(i)
