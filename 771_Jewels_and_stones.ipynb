# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
class Solution:
    def numJewelsInStones(self, jewels: str, stones: str) -> int:
        c = 0
        j = [x for x in jewels]
        s = [i for i in stones]
        for i in s:
            if i in j:
                c = c+1
        return c
