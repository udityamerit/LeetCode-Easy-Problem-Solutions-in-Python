# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
class Solution:
    def sortArrayByParity(self, nums: List[int]) -> List[int]:
        l = [i for i in nums if i%2==0]
        print(l)
        k = [i for i in nums if i%2==1]
        print(k)
        return l+k

# %% [markdown]
# #### Solution 2
